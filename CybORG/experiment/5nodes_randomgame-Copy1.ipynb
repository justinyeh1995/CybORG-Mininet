# %% [markdown]
# #### A 3 node experiment to demonstrate the network simulation and attack process in cyborg

# %%
import random
from os.path import dirname
from pprint import pprint
import inspect
from CybORG import CybORG
from CybORG.Simulator.Scenarios import FileReaderScenarioGenerator
from CybORG.Simulator.Actions import *
from CybORG.Agents import RandomAgent
import numpy as np
import time
import sys
print(sys.version)


path = str(inspect.getfile(CybORG))
#path= dirname(path) + f'/Simulator/Scenarios/scenario_files/Scenario_3nodes.yaml'

path = f'D:/RAMPART_sim/CybORG/CybORG/Simulator/Scenarios/scenario_files/Scenario_5nodes_randomgame.yaml'

#path = f'D:/RAMPART_sim/CybORG/CybORG/Simulator/Scenarios/scenario_files/NetworkDesign.yaml'

#Scenario generator
sg = FileReaderScenarioGenerator(path)   # Scenario generator (converts YAML file to Scenario file type )
print('Scenario file path is:',path,'sg is:',type(sg))

env = CybORG(scenario_generator=sg) # defined in env.py script.
#pprint(dir(env))

#pprint('IP map of network is:',env.get_ip_map())
#pprint('Red agent state is:',env.get_agent_state('Red'))
#pprint('Red agent action space is:',env.get_action_space('Red'))
print('==> IP map of network is:')
pprint(env.get_ip_map())



ips= env.get_ip_map()
userip= ips['User0']
print('-> user ip to attack is:',userip)





results = env.reset(agent='Blue')
# Out:
# path is: d:\rampart_sim\cyborg\CybORG\env.py
# 3.7.16 (default, Jan 17 2023, 16:06:28) [MSC v.1916 64 bit (AMD64)]
# Scenario file path is: D:/RAMPART_sim/CybORG/CybORG/Simulator/Scenarios/scenario_files/Scenario_5nodes_randomgame.yaml sg is: <class 'CybORG.Simulator.Scenarios.FileReaderScenarioGenerator.FileReaderScenarioGenerator'>
# env is: sim
# ==> IP map of network is:
# {'Defender': IPv4Address('10.0.244.241'),
#  'User0': IPv4Address('10.0.244.248'),
#  'User1': IPv4Address('10.0.244.242'),
#  'User2': IPv4Address('10.0.244.243'),
#  'User3': IPv4Address('10.0.244.246'),
#  'User4': IPv4Address('10.0.244.252'),
#  'User_router': IPv4Address('10.0.244.245')}
# -> user ip to attack is: 10.0.244.248
# Agent Interfaces are: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x0000022A4D2E3908>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x0000022A4D2E38C8>}
# C:\Users\vardh\AppData\Local\miniconda3\envs\cyborg\lib\site-packages\gym\utils\seeding.py:48: DeprecationWarning: WARN: Function `rng.randint(low, [high, size, dtype])` is marked as deprecated and will be removed in the future. Please use `rng.integers(low, [high, size, dtype])` instead.
#   "Function `rng.randint(low, [high, size, dtype])` is marked as deprecated "

# %%
print('==> Blue Agents observed state  is:')
pprint(env.get_agent_state('Blue'))
# Out:
# ==> Blue Agents observed state  is:
# {'Defender': {'Interface': [{'IP Address': IPv4Address('10.0.78.101'),
#                              'Interface Name': 'eth0',
#                              'Subnet': IPv4Network('10.0.78.96/28')}],
#               'Processes': [{'PID': 2295, 'Username': 'ubuntu'},
#                             {'PID': 2296, 'Username': 'ubuntu'}],
#               'Sessions': [{'Agent': 'Blue',
#                             'ID': 0,
#                             'PID': 2295,
#                             'Timeout': 0,
#                             'Type': <SessionType.VELOCIRAPTOR_SERVER: 8>,
#                             'Username': 'ubuntu'},
#                            {'Agent': 'Blue',
#                             'ID': 6,
#                             'PID': 2296,
#                             'Timeout': 0,
#                             'Type': <SessionType.VELOCIRAPTOR_CLIENT: 7>,
#                             'Username': 'ubuntu'}],
#               'System info': {'Architecture': <Architecture.x64: 2>,
#                               'Hostname': 'Defender',
#                               'OSDistribution': <OperatingSystemDistribution.UBUNTU: 8>,
#                               'OSType': <OperatingSystemType.LINUX: 3>,
#                               'OSVersion': <OperatingSystemVersion.U18_04_3: 6>,
#                               'position': array([0., 0.])},
#               'User Info': [{'Groups': [{'GID': 0}], 'Username': 'root'},
#                             {'Groups': [{'GID': 1000}], 'Username': 'ubuntu'}]},
#  'User0': {'Interface': [{'IP Address': IPv4Address('10.0.78.97'),
#                           'Interface Name': 'eth0',
#                           'Subnet': IPv4Network('10.0.78.96/28')}],
#            'Processes': [{'PID': 3370, 'Username': 'ubuntu'}],
#            'Sessions': [{'Agent': 'Blue',
#                          'ID': 1,
#                          'PID': 3370,
#                          'Timeout': 0,
#                          'Type': <SessionType.VELOCIRAPTOR_CLIENT: 7>,
#                          'Username': 'ubuntu'}],
#            'System info': {'Architecture': <Architecture.x64: 2>,
#                            'Hostname': 'User0',
#                            'OSDistribution': <OperatingSystemDistribution.WINDOWS_SVR_2008: 4>,
#                            'OSType': <OperatingSystemType.WINDOWS: 2>,
#                            'OSVersion': <OperatingSystemVersion.W6_1_7601: 13>,
#                            'position': array([0., 0.])},
#            'User Info': [{'Groups': [{'GID': 0}], 'Username': 'Administrator'},
#                          {'Username': 'GreenAgent'},
#                          {'Groups': [{'GID': 0}],
#                           'Password': 'vagrant',
#                           'Username': 'vagrant'},
#                          {'Username': 'SYSTEM'}]},
#  'User1': {'Interface': [{'IP Address': IPv4Address('10.0.78.100'),
#                           'Interface Name': 'eth0',
#                           'Subnet': IPv4Network('10.0.78.96/28')}],
#            'Processes': [{'PID': 1107, 'Username': 'ubuntu'}],
#            'Sessions': [{'Agent': 'Blue',
#                          'ID': 2,
#                          'PID': 1107,
#                          'Timeout': 0,
#                          'Type': <SessionType.VELOCIRAPTOR_CLIENT: 7>,
#                          'Username': 'ubuntu'}],
#            'System info': {'Architecture': <Architecture.x64: 2>,
#                            'Hostname': 'User1',
#                            'OSDistribution': <OperatingSystemDistribution.UBUNTU: 8>,
#                            'OSType': <OperatingSystemType.LINUX: 3>,
#                            'OSVersion': <OperatingSystemVersion.U18_04_3: 6>,
#                            'position': array([0., 0.])},
#            'User Info': [{'Groups': [{'GID': 0}], 'Username': 'root'},
#                          {'Groups': [{'GID': 33}], 'Username': 'www-data'},
#                          {'Groups': [{'GID': 1001}],
#                           'Password': 'raspberry',
#                           'Username': 'pi'},
#                          {'Groups': [{'GID': 1000}], 'Username': 'ubuntu'},
#                          {'Groups': [{'GID': 1001}],
#                           'Username': 'GreenAgent'}]},
#  'User2': {'Interface': [{'IP Address': IPv4Address('10.0.78.108'),
#                           'Interface Name': 'eth0',
#                           'Subnet': IPv4Network('10.0.78.96/28')}],
#            'Processes': [{'PID': 4403, 'Username': 'ubuntu'}],
#            'Sessions': [{'Agent': 'Blue',
#                          'ID': 3,
#                          'PID': 4403,
#                          'Timeout': 0,
#                          'Type': <SessionType.VELOCIRAPTOR_CLIENT: 7>,
#                          'Username': 'ubuntu'}],
#            'System info': {'Architecture': <Architecture.x64: 2>,
#                            'Hostname': 'User2',
#                            'OSDistribution': <OperatingSystemDistribution.WINDOWS_SVR_2008: 4>,
#                            'OSType': <OperatingSystemType.WINDOWS: 2>,
#                            'OSVersion': <OperatingSystemVersion.W6_1_7601: 13>,
#                            'position': array([0., 0.])},
#            'User Info': [{'Groups': [{'GID': 0}], 'Username': 'Administrator'},
#                          {'Username': 'GreenAgent'},
#                          {'Groups': [{'GID': 0}],
#                           'Password': 'vagrant',
#                           'Username': 'vagrant'},
#                          {'Username': 'SYSTEM'}]},
#  'User3': {'Interface': [{'IP Address': IPv4Address('10.0.78.109'),
#                           'Interface Name': 'eth0',
#                           'Subnet': IPv4Network('10.0.78.96/28')}],
#            'Processes': [{'PID': 1105, 'Username': 'ubuntu'}],
#            'Sessions': [{'Agent': 'Blue',
#                          'ID': 4,
#                          'PID': 1105,
#                          'Timeout': 0,
#                          'Type': <SessionType.VELOCIRAPTOR_CLIENT: 7>,
#                          'Username': 'ubuntu'}],
#            'System info': {'Architecture': <Architecture.x64: 2>,
#                            'Hostname': 'User3',
#                            'OSDistribution': <OperatingSystemDistribution.UBUNTU: 8>,
#                            'OSType': <OperatingSystemType.LINUX: 3>,
#                            'OSVersion': <OperatingSystemVersion.U18_04_3: 6>,
#                            'position': array([0., 0.])},
#            'User Info': [{'Groups': [{'GID': 0}], 'Username': 'root'},
#                          {'Groups': [{'GID': 33}], 'Username': 'www-data'},
#                          {'Groups': [{'GID': 1001}],
#                           'Password': 'raspberry',
#                           'Username': 'pi'},
#                          {'Groups': [{'GID': 1000}], 'Username': 'ubuntu'},
#                          {'Groups': [{'GID': 1001}],
#                           'Username': 'GreenAgent'}]},
#  'User4': {'Interface': [{'IP Address': IPv4Address('10.0.78.107'),
#                           'Interface Name': 'eth0',
#                           'Subnet': IPv4Network('10.0.78.96/28')}],
#            'Processes': [{'PID': 1109, 'Username': 'ubuntu'}],
#            'Sessions': [{'Agent': 'Blue',
#                          'ID': 5,
#                          'PID': 1109,
#                          'Timeout': 0,
#                          'Type': <SessionType.VELOCIRAPTOR_CLIENT: 7>,
#                          'Username': 'ubuntu'}],
#            'System info': {'Architecture': <Architecture.x64: 2>,
#                            'Hostname': 'User4',
#                            'OSDistribution': <OperatingSystemDistribution.UBUNTU: 8>,
#                            'OSType': <OperatingSystemType.LINUX: 3>,
#                            'OSVersion': <OperatingSystemVersion.U18_04_3: 6>,
#                            'position': array([0., 0.])},
#            'User Info': [{'Groups': [{'GID': 0}], 'Username': 'root'},
#                          {'Groups': [{'GID': 33}], 'Username': 'www-data'},
#                          {'Groups': [{'GID': 1001}],
#                           'Password': 'raspberry',
#                           'Username': 'pi'},
#                          {'Groups': [{'GID': 1000}], 'Username': 'ubuntu'},
#                          {'Groups': [{'GID': 1001}],
#                           'Username': 'GreenAgent'}]},
#  'success': <TrinaryEnum.UNKNOWN: 2>}

# %%
action = Isolate(session=0, agent='Blue',hostname='User1')
results = env.step(action=action,agent='Blue')
obs = results.observation
pprint(obs)
# Out:
# action is: {'Blue': Isolate User1}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x0000022A4D2E3908>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x0000022A4D2E38C8>}
# action is: {'Blue': Isolate User1, 'Red': Sleep}
# --> in actions
# In simcontroller execute action
# action is: Isolate User1 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Isolate.Isolate'>
# %%%%%%%%%%%%%%
# Session is: [<CybORG.Simulator.Session.Session object at 0x0000022A4D301FC8>]
# State is: ['DEBUG2', 'DEBUG2_LVL', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_format_log_msg', '_initialise_state', '_log_debug', '_log_debug2', '_log_error', '_log_header', '_log_info', '_log_warning', 'add_file', 'add_session', 'add_user', 'blocks', 'connected_components', 'critical', 'debug', 'debug2', 'dist', 'error', 'get_logger', 'get_session_from_pid', 'get_ssh_tunnel_logger', 'get_subnet_containing_ip_address', 'get_true_state', 'header', 'hosts', 'info', 'ip_addresses', 'kill_process', 'link_diagram', 'logger_name', 'np_random', 'operational_firewall', 'original_time', 'reboot_host', 'remove_process', 'scenario', 'sessions', 'sessions_count', 'setLevel', 'set_np_random', 'setup', 'setup_data_links', 'sshtunnel_logger_name', 'start_service', 'step', 'stop_service', 'subnet_name_to_cidr', 'subnets', 'time', 'update_data_links', 'warning']
# {'blocks': {},
#  'connected_components': [{'Defender',
#                            'User0',
#                            'User1',
#                            'User2',
#                            'User3',
#                            'User4',
#                            'User_router'}],
#  'hosts': {'Defender': <CybORG.Simulator.Host.Host object at 0x0000022A4D1A10C8>,
#            'User0': <CybORG.Simulator.Host.Host object at 0x0000022A4D2FE0C8>,
#            'User1': <CybORG.Simulator.Host.Host object at 0x0000022A4D2FE948>,
#            'User2': <CybORG.Simulator.Host.Host object at 0x0000022A4D2FF648>,
#            'User3': <CybORG.Simulator.Host.Host object at 0x0000022A4D300048>,
#            'User4': <CybORG.Simulator.Host.Host object at 0x0000022A4D300BC8>,
#            'User_router': <CybORG.Simulator.Host.Host object at 0x0000022A4D3018C8>},
#  'ip_addresses': {IPv4Address('10.0.78.97'): 'User0',
#                   IPv4Address('10.0.78.100'): 'User1',
#                   IPv4Address('10.0.78.101'): 'Defender',
#                   IPv4Address('10.0.78.107'): 'User4',
#                   IPv4Address('10.0.78.108'): 'User2',
#                   IPv4Address('10.0.78.109'): 'User3',
#                   IPv4Address('10.0.78.110'): 'User_router'},
#  'link_diagram': <networkx.classes.graph.Graph object at 0x0000022A4D312508>,
#  'np_random': RandomNumberGenerator(PCG64) at 0x22A4CFA3E48,
#  'operational_firewall': False,
#  'original_time': datetime.datetime(2020, 1, 1, 0, 0),
#  'scenario': <CybORG.Shared.Scenario.Scenario object at 0x0000022A4D112C08>,
#  'sessions': {'Blue': {0: <CybORG.Simulator.Session.VelociraptorServer object at 0x0000022A4D301E48>,
#                        1: <CybORG.Simulator.Session.Session object at 0x0000022A4D301F48>,
#                        2: <CybORG.Simulator.Session.Session object at 0x0000022A4D301FC8>,
#                        3: <CybORG.Simulator.Session.Session object at 0x0000022A4D303188>,
#                        4: <CybORG.Simulator.Session.Session object at 0x0000022A4D3032C8>,
#                        5: <CybORG.Simulator.Session.Session object at 0x0000022A4D303348>,
#                        6: <CybORG.Simulator.Session.Session object at 0x0000022A4D3034C8>},
#               'Red': {0: <CybORG.Simulator.Session.RedAbstractSession object at 0x0000022A4D3035C8>}},
#  'sessions_count': {'Blue': 7, 'Red': 1},
#  'step': 0,
#  'subnet_name_to_cidr': {'User': IPv4Network('10.0.78.96/28')},
#  'subnets': {IPv4Network('10.0.78.96/28'): <CybORG.Simulator.Subnet.Subnet object at 0x0000022A4D1A1C08>},
#  'time': datetime.datetime(2020, 1, 1, 0, 0)}
# --> in observations
# {'success': <TrinaryEnum.TRUE: 1>}

# %% [raw]
# ##### Observed state from the perspective of red agent

# %%
print('==> Red Agents observed state  is:')
pprint(env.get_agent_state('Red'))
# Out:
# ==> Red Agents observed state  is:
# {'User0': {'Interface': [{'IP Address': IPv4Address('10.0.173.97'),
#                           'Interface Name': 'eth0',
#                           'Subnet': IPv4Network('10.0.173.96/28')}],
#            'Processes': [{'PID': 3377, 'Username': 'SYSTEM'}],
#            'Sessions': [{'Agent': 'Red',
#                          'ID': 0,
#                          'PID': 3377,
#                          'Timeout': 0,
#                          'Type': <SessionType.RED_ABSTRACT_SESSION: 10>,
#                          'Username': 'SYSTEM'}],
#            'System info': {'Architecture': <Architecture.x64: 2>,
#                            'Hostname': 'User0',
#                            'OSDistribution': <OperatingSystemDistribution.WINDOWS_SVR_2008: 4>,
#                            'OSType': <OperatingSystemType.WINDOWS: 2>,
#                            'OSVersion': <OperatingSystemVersion.W6_1_7601: 13>,
#                            'position': array([0., 0.])}},
#  'success': <TrinaryEnum.UNKNOWN: 2>}

# %%
print('==> Blue Agents observed state  is:')
pprint(env.get_agent_state('Blue'))
# Out:
# ==> Blue Agents observed state  is:
# {'Defender': {'Interface': [{'IP Address': IPv4Address('10.0.173.109'),
#                              'Interface Name': 'eth0',
#                              'Subnet': IPv4Network('10.0.173.96/28')}],
#               'Processes': [{'PID': 2289, 'Username': 'ubuntu'},
#                             {'PID': 2292, 'Username': 'ubuntu'}],
#               'Sessions': [{'Agent': 'Blue',
#                             'ID': 0,
#                             'PID': 2289,
#                             'Timeout': 0,
#                             'Type': <SessionType.VELOCIRAPTOR_SERVER: 8>,
#                             'Username': 'ubuntu'},
#                            {'Agent': 'Blue',
#                             'ID': 6,
#                             'PID': 2292,
#                             'Timeout': 0,
#                             'Type': <SessionType.VELOCIRAPTOR_CLIENT: 7>,
#                             'Username': 'ubuntu'}],
#               'System info': {'Architecture': <Architecture.x64: 2>,
#                               'Hostname': 'Defender',
#                               'OSDistribution': <OperatingSystemDistribution.UBUNTU: 8>,
#                               'OSType': <OperatingSystemType.LINUX: 3>,
#                               'OSVersion': <OperatingSystemVersion.U18_04_3: 6>,
#                               'position': array([0., 0.])},
#               'User Info': [{'Groups': [{'GID': 0}], 'Username': 'root'},
#                             {'Groups': [{'GID': 1000}], 'Username': 'ubuntu'}]},
#  'User0': {'Interface': [{'IP Address': IPv4Address('10.0.173.97'),
#                           'Interface Name': 'eth0',
#                           'Subnet': IPv4Network('10.0.173.96/28')}],
#            'Processes': [{'PID': 3375, 'Username': 'ubuntu'}],
#            'Sessions': [{'Agent': 'Blue',
#                          'ID': 1,
#                          'PID': 3375,
#                          'Timeout': 0,
#                          'Type': <SessionType.VELOCIRAPTOR_CLIENT: 7>,
#                          'Username': 'ubuntu'}],
#            'System info': {'Architecture': <Architecture.x64: 2>,
#                            'Hostname': 'User0',
#                            'OSDistribution': <OperatingSystemDistribution.WINDOWS_SVR_2008: 4>,
#                            'OSType': <OperatingSystemType.WINDOWS: 2>,
#                            'OSVersion': <OperatingSystemVersion.W6_1_7601: 13>,
#                            'position': array([0., 0.])},
#            'User Info': [{'Groups': [{'GID': 0}], 'Username': 'Administrator'},
#                          {'Username': 'GreenAgent'},
#                          {'Groups': [{'GID': 0}],
#                           'Password': 'vagrant',
#                           'Username': 'vagrant'},
#                          {'Username': 'SYSTEM'}]},
#  'User1': {'Interface': [{'IP Address': IPv4Address('10.0.173.103'),
#                           'Interface Name': 'eth0',
#                           'Subnet': IPv4Network('10.0.173.96/28')}],
#            'Processes': [{'PID': 1103, 'Username': 'ubuntu'}],
#            'Sessions': [{'Agent': 'Blue',
#                          'ID': 2,
#                          'PID': 1103,
#                          'Timeout': 0,
#                          'Type': <SessionType.VELOCIRAPTOR_CLIENT: 7>,
#                          'Username': 'ubuntu'}],
#            'System info': {'Architecture': <Architecture.x64: 2>,
#                            'Hostname': 'User1',
#                            'OSDistribution': <OperatingSystemDistribution.UBUNTU: 8>,
#                            'OSType': <OperatingSystemType.LINUX: 3>,
#                            'OSVersion': <OperatingSystemVersion.U18_04_3: 6>,
#                            'position': array([0., 0.])},
#            'User Info': [{'Groups': [{'GID': 0}], 'Username': 'root'},
#                          {'Groups': [{'GID': 33}], 'Username': 'www-data'},
#                          {'Groups': [{'GID': 1001}],
#                           'Password': 'raspberry',
#                           'Username': 'pi'},
#                          {'Groups': [{'GID': 1000}], 'Username': 'ubuntu'},
#                          {'Groups': [{'GID': 1001}],
#                           'Username': 'GreenAgent'}]},
#  'User2': {'Interface': [{'IP Address': IPv4Address('10.0.173.99'),
#                           'Interface Name': 'eth0',
#                           'Subnet': IPv4Network('10.0.173.96/28')}],
#            'Processes': [{'PID': 4404, 'Username': 'ubuntu'}],
#            'Sessions': [{'Agent': 'Blue',
#                          'ID': 3,
#                          'PID': 4404,
#                          'Timeout': 0,
#                          'Type': <SessionType.VELOCIRAPTOR_CLIENT: 7>,
#                          'Username': 'ubuntu'}],
#            'System info': {'Architecture': <Architecture.x64: 2>,
#                            'Hostname': 'User2',
#                            'OSDistribution': <OperatingSystemDistribution.WINDOWS_SVR_2008: 4>,
#                            'OSType': <OperatingSystemType.WINDOWS: 2>,
#                            'OSVersion': <OperatingSystemVersion.W6_1_7601: 13>,
#                            'position': array([0., 0.])},
#            'User Info': [{'Groups': [{'GID': 0}], 'Username': 'Administrator'},
#                          {'Username': 'GreenAgent'},
#                          {'Groups': [{'GID': 0}],
#                           'Password': 'vagrant',
#                           'Username': 'vagrant'},
#                          {'Username': 'SYSTEM'}]},
#  'User3': {'Interface': [{'IP Address': IPv4Address('10.0.173.106'),
#                           'Interface Name': 'eth0',
#                           'Subnet': IPv4Network('10.0.173.96/28')}],
#            'Processes': [{'PID': 1108, 'Username': 'ubuntu'}],
#            'Sessions': [{'Agent': 'Blue',
#                          'ID': 4,
#                          'PID': 1108,
#                          'Timeout': 0,
#                          'Type': <SessionType.VELOCIRAPTOR_CLIENT: 7>,
#                          'Username': 'ubuntu'}],
#            'System info': {'Architecture': <Architecture.x64: 2>,
#                            'Hostname': 'User3',
#                            'OSDistribution': <OperatingSystemDistribution.UBUNTU: 8>,
#                            'OSType': <OperatingSystemType.LINUX: 3>,
#                            'OSVersion': <OperatingSystemVersion.U18_04_3: 6>,
#                            'position': array([0., 0.])},
#            'User Info': [{'Groups': [{'GID': 0}], 'Username': 'root'},
#                          {'Groups': [{'GID': 33}], 'Username': 'www-data'},
#                          {'Groups': [{'GID': 1001}],
#                           'Password': 'raspberry',
#                           'Username': 'pi'},
#                          {'Groups': [{'GID': 1000}], 'Username': 'ubuntu'},
#                          {'Groups': [{'GID': 1001}],
#                           'Username': 'GreenAgent'}]},
#  'User4': {'Interface': [{'IP Address': IPv4Address('10.0.173.108'),
#                           'Interface Name': 'eth0',
#                           'Subnet': IPv4Network('10.0.173.96/28')}],
#            'Processes': [{'PID': 1111, 'Username': 'ubuntu'}],
#            'Sessions': [{'Agent': 'Blue',
#                          'ID': 5,
#                          'PID': 1111,
#                          'Timeout': 0,
#                          'Type': <SessionType.VELOCIRAPTOR_CLIENT: 7>,
#                          'Username': 'ubuntu'}],
#            'System info': {'Architecture': <Architecture.x64: 2>,
#                            'Hostname': 'User4',
#                            'OSDistribution': <OperatingSystemDistribution.UBUNTU: 8>,
#                            'OSType': <OperatingSystemType.LINUX: 3>,
#                            'OSVersion': <OperatingSystemVersion.U18_04_3: 6>,
#                            'position': array([0., 0.])},
#            'User Info': [{'Groups': [{'GID': 0}], 'Username': 'root'},
#                          {'Groups': [{'GID': 33}], 'Username': 'www-data'},
#                          {'Groups': [{'GID': 1001}],
#                           'Password': 'raspberry',
#                           'Username': 'pi'},
#                          {'Groups': [{'GID': 1000}], 'Username': 'ubuntu'},
#                          {'Groups': [{'GID': 1001}],
#                           'Username': 'GreenAgent'}]},
#  'success': <TrinaryEnum.UNKNOWN: 2>}

# %% [markdown]
# #### Action space to the red agent:

# %%
print('==> Red Agent action space is:')
pprint(env.get_action_space('Red'))
red_actions= env.get_action_space('Red')["action"]
print(red_actions)
# Out:
# ==> Red Agent action space is:
# {'action': {<class 'CybORG.Simulator.Actions.Action.Sleep'>: True,
#             <class 'CybORG.Simulator.Actions.AbstractActions.ExploitRemoteService.ExploitRemoteService'>: True,
#             <class 'CybORG.Simulator.Actions.AbstractActions.DiscoverNetworkServices.DiscoverNetworkServices'>: True,
#             <class 'CybORG.Simulator.Actions.AbstractActions.DiscoverRemoteSystems.DiscoverRemoteSystems'>: True},
#  'agent': {'Red': True},
#  'hostname': {'Defender': False,
#               'User0': True,
#               'User1': False,
#               'User2': False,
#               'User3': False,
#               'User4': False,
#               'User_router': False},
#  'ip_address': {IPv4Address('10.0.173.97'): True,
#                 IPv4Address('10.0.173.99'): False,
#                 IPv4Address('10.0.173.101'): False,
#                 IPv4Address('10.0.173.103'): False,
#                 IPv4Address('10.0.173.106'): False,
#                 IPv4Address('10.0.173.108'): False,
#                 IPv4Address('10.0.173.109'): False},
#  'password': {'raspberry': False, 'vagrant': False},
#  'port': {21: False,
#           22: False,
#           25: False,
#           53: False,
#           80: False,
#           135: False,
#           139: False,
#           443: False,
#           445: False,
#           3389: False,
#           3390: False},
#  'process': {1: False,
#              4: False,
#              389: False,
#              407: False,
#              409: False,
#              560: False,
#              656: False,
#              790: False,
#              802: False,
#              803: False,
#              807: False,
#              824: False,
#              825: False,
#              827: False,
#              832: False,
#              844: False,
#              847: False,
#              852: False,
#              853: False,
#              863: False,
#              867: False,
#              875: False,
#              879: False,
#              884: False,
#              1091: False,
#              1100: False,
#              1101: False,
#              1102: False,
#              1103: False,
#              1108: False,
#              1111: False,
#              1370: False,
#              1432: False,
#              2288: False,
#              2289: False,
#              2292: False,
#              3344: False,
#              3368: False,
#              3375: False,
#              3377: True,
#              4400: False,
#              4404: False},
#  'session': {0: True},
#  'subnet': {IPv4Network('10.0.173.96/28'): True},
#  'target_session': {0: True,
#                     1: False,
#                     2: False,
#                     3: False,
#                     4: False,
#                     5: False,
#                     6: False,
#                     7: False},
#  'username': {'Administrator': False,
#               'GreenAgent': False,
#               'SYSTEM': False,
#               'pi': False,
#               'root': False,
#               'ubuntu': False,
#               'vagrant': False,
#               'www-data': False}}
# {<class 'CybORG.Simulator.Actions.Action.Sleep'>: True, <class 'CybORG.Simulator.Actions.AbstractActions.DiscoverRemoteSystems.DiscoverRemoteSystems'>: True, <class 'CybORG.Simulator.Actions.AbstractActions.DiscoverNetworkServices.DiscoverNetworkServices'>: True, <class 'CybORG.Simulator.Actions.AbstractActions.ExploitRemoteService.ExploitRemoteService'>: True}

# %%
print('==> Blue Agent action space is:')
pprint(env.get_action_space('Blue'))
# Out:
# ==> Blue Agent action space is:
# {'action': {<class 'CybORG.Simulator.Actions.Action.Sleep'>: True,
#             <class 'CybORG.Simulator.Actions.AbstractActions.Remove.Remove'>: True,
#             <class 'CybORG.Simulator.Actions.AbstractActions.Analyse.Analyse'>: True,
#             <class 'CybORG.Simulator.Actions.AbstractActions.Isolate.Isolate'>: True},
#  'agent': {'Blue': True},
#  'hostname': {'Defender': True,
#               'User0': True,
#               'User1': True,
#               'User2': True,
#               'User3': True,
#               'User4': True,
#               'User_router': False},
#  'ip_address': {IPv4Address('10.0.173.97'): True,
#                 IPv4Address('10.0.173.99'): True,
#                 IPv4Address('10.0.173.101'): False,
#                 IPv4Address('10.0.173.103'): True,
#                 IPv4Address('10.0.173.106'): True,
#                 IPv4Address('10.0.173.108'): True,
#                 IPv4Address('10.0.173.109'): True},
#  'password': {'raspberry': True, 'vagrant': True},
#  'port': {21: False,
#           22: False,
#           25: False,
#           53: False,
#           80: False,
#           135: False,
#           139: False,
#           443: False,
#           445: False,
#           3389: False,
#           3390: False},
#  'process': {1: False,
#              4: False,
#              389: False,
#              407: False,
#              409: False,
#              560: False,
#              656: False,
#              790: False,
#              802: False,
#              803: False,
#              807: False,
#              824: False,
#              825: False,
#              827: False,
#              832: False,
#              844: False,
#              847: False,
#              852: False,
#              853: False,
#              863: False,
#              867: False,
#              875: False,
#              879: False,
#              884: False,
#              1091: False,
#              1100: False,
#              1101: False,
#              1102: False,
#              1103: True,
#              1108: True,
#              1111: True,
#              1370: False,
#              1432: False,
#              2288: False,
#              2289: True,
#              2292: True,
#              3344: False,
#              3368: False,
#              3375: True,
#              3377: False,
#              4400: False,
#              4404: True},
#  'session': {0: True},
#  'subnet': {IPv4Network('10.0.173.96/28'): True},
#  'target_session': {0: True,
#                     1: True,
#                     2: True,
#                     3: True,
#                     4: True,
#                     5: True,
#                     6: True,
#                     7: False},
#  'username': {'Administrator': True,
#               'GreenAgent': True,
#               'SYSTEM': True,
#               'pi': True,
#               'root': True,
#               'ubuntu': True,
#               'vagrant': True,
#               'www-data': True}}

# %% [markdown]
# #### Attack action : DiscoverNetworkServices
# It allow the red agent to identify services on a host as a prerequisite for running an exploit.
# It Calls the low level action 'PortScan' then modifies the observation. The outcome is all open ports running on the host.  It must be used on a host to successfully run the high level action ExploitRemoteServices.

# %%
#creating and executing port discovery attack on user network 
action = DiscoverNetworkServices(session=0,agent='Red',ip_address=userip)
results = env.step(action=action,agent='Red')
print('==> Red agent state after discover network services attack:')
pprint(results.observation)
# Out:
# ==> Red agent state after discover network services attack:
# {'10.0.173.216': {'Interface': [{'IP Address': IPv4Address('10.0.173.216')}],
#                   'Processes': [{'Connections': [{'local_address': IPv4Address('10.0.173.216'),
#                                                   'local_port': 22}]},
#                                 {'Connections': [{'local_address': IPv4Address('10.0.173.216'),
#                                                   'local_port': 21}]}]},
#  'success': <TrinaryEnum.TRUE: 1>}

# %%
#creating and executing port discovery attack on user network 
action_space = env.get_action_space('Red')
#pprint(action_space)
subnets=action_space["subnet"]
known_subnets = [subnet for subnet in subnets if subnets[subnet]]
subnet = known_subnets[0]

print('Subnet visible to red is:',subnet)
action = DiscoverRemoteSystems(subnet = subnet, session=0,agent='Red')
results = env.step(action=action,agent='Red')
print('==> Red agent state after discover network services attack:')
pprint(results.observation)
# Out:
# Subnet visible to red is: 10.0.173.208/28
# ==> Red agent state after discover network services attack:
# {'10.0.173.216': {'Interface': [{'IP Address': IPv4Address('10.0.173.216'),
#                                  'Subnet': IPv4Network('10.0.173.208/28')}]},
#  '10.0.173.222': {'Interface': [{'IP Address': IPv4Address('10.0.173.222'),
#                                  'Subnet': IPv4Network('10.0.173.208/28')}]},
#  'success': <TrinaryEnum.TRUE: 1>}

# %% [markdown]
# #### Attack action : ExploitRemoteServices
# It allow the red agent to examines the target host and returns a selected applicable escalate action if any, as well as processes that are required to be genuine.

# %%
#creating and executing attack on user network (can we attack on router? -dont know)
action = ExploitRemoteService(ip_address=userip,session=0,agent='Red')
results = env.step(action=action,agent='Red')
print('==> Red agent state after exploit attack:')
pprint(results.observation)
# Out:
# ==> Red agent state after exploit attack:
# {'10.0.173.216': {'Interface': [{'IP Address': IPv4Address('10.0.173.216')}],
#                   'Processes': [{'Connections': [{'Status': <ProcessState.OPEN: 2>,
#                                                   'local_address': IPv4Address('10.0.173.216'),
#                                                   'local_port': 22}],
#                                  'Process Type': <ProcessType.SSH: 2>},
#                                 {'Connections': [{'local_address': IPv4Address('10.0.173.216'),
#                                                   'local_port': 51418,
#                                                   'remote_address': IPv4Address('10.0.173.216'),
#                                                   'remote_port': 22}]},
#                                 {'Connections': [{'local_address': IPv4Address('10.0.173.216'),
#                                                   'local_port': 22,
#                                                   'remote_address': IPv4Address('10.0.173.216'),
#                                                   'remote_port': 51418}],
#                                  'Process Type': <ProcessType.SSH: 2>}],
#                   'Sessions': [{'Agent': 'Red',
#                                 'ID': 1,
#                                 'Type': <SessionType.SSH: 2>,
#                                 'Username': 'vagrant'}],
#                   'System info': {'Hostname': 'User0',
#                                   'OSType': <OperatingSystemType.WINDOWS: 2>}},
#  'success': <TrinaryEnum.TRUE: 1>}

# %%
red_actions=['Sleep','DiscoverNetworkServices','ExploitRemoteService']
blue_actions=['Sleep','Analyse','Remove']
states=['blue','green','orange','red']
initial_state='blue'
log=[] #log [init_state,red_Action,state,blue_action,state,....] 
log.append(initial_state)

# %%
steps=10
random_actions=np.random.randint(3,size=steps*2)
print('Ranom actions are:',random_actions)
for i in range(0,len(random_actions),2):
    #first red random action
    red_action_id=random_actions[i]
    red_action=red_actions[red_action_id]
    print('Red agent action is:',red_action)
    log.append(red_action)
    #results = env.step(action=action, agent='Red')
    
    #todo: log state of node here
    
    
    #second blue random action
    blue_action_id=random_actions[i+1]
    blue_action= blue_actions[blue_action_id]
    print('Blue agent action is:',blue_action)
    log.append(blue_action)  
   
    
    #results = env.step(action=action, agent='Red')
     #todo: log state of node here
print('log is:',log)
# Out:
# Ranom actions are: [2 1 2 1 2 0 1 2 0 2 2 0 0 2 0 0 0 0 2 2]
# Red agent action is: ExploitRemoteService
# Blue agent action is: Analyse
# Red agent action is: ExploitRemoteService
# Blue agent action is: Analyse
# Red agent action is: ExploitRemoteService
# Blue agent action is: Sleep
# Red agent action is: DiscoverNetworkServices
# Blue agent action is: Remove
# Red agent action is: Sleep
# Blue agent action is: Remove
# Red agent action is: ExploitRemoteService
# Blue agent action is: Sleep
# Red agent action is: Sleep
# Blue agent action is: Remove
# Red agent action is: Sleep
# Blue agent action is: Sleep
# Red agent action is: Sleep
# Blue agent action is: Sleep
# Red agent action is: ExploitRemoteService
# Blue agent action is: Remove
# log is: ['blue', 'ExploitRemoteService', 'Analyse', 'ExploitRemoteService', 'Analyse', 'ExploitRemoteService', 'Sleep', 'DiscoverNetworkServices', 'Remove', 'Sleep', 'Remove', 'ExploitRemoteService', 'Sleep', 'Sleep', 'Remove', 'Sleep', 'Sleep', 'Sleep', 'Sleep', 'ExploitRemoteService', 'Remove']
